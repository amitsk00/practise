# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='UTF-8'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['ceramidium',
#  'outshrill',
#  'bacterioblast',
#  'nuzzle',
#  'brayerin',
#  'beshadow',
#  'psychopathia',
#  'uncondemned',
#  'decidable',
#  'procurator',
#  'defraud',
#  'outglitter',
#  'pirene',
#  'fraternality',
#  'raptores',
#  'stingingly',
#  'inmost',
#  'homaxonial',
#  'priggishly',
#  'microsphere',
#  'shakefork',
#  'siriometer',
#  'trinkety',
#  'mutillidae',
#  'poikilocythemia',
#  'pervicaciously',
#  'sciapod',
#  'unodoriferous',
#  'filemot',
#  'gourmet',
#  'nondrying',
#  'atavistic',
#  'laglast',
#  'refrigerative',
#  'chita',
#  'uncontemptuous',
#  'olearia',
#  'drinking',
#  'compilement',
#  'reignite',
#  'operant',
#  'duenna',
#  'mainmortable',
#  'hippopotamoid',
#  'deliquium',
#  'dulotic',
#  'agnoetae',
#  'dimble',
#  'impermeable',
#  'outpeople',
#  'equiprobabilism',
#  'feijoa',
#  'tricarbon',
#  'hastefully',
#  'rabbitmouth',
#  'euthanasy',
#  'middlebreaker',
#  'fulzie',
#  'underchord',
#  'hypsometrical',
#  'fratority',
#  'poseur',
#  'ligger',
#  'azoxonium',
#  'quinquedentate',
#  'snooded',
#  'holidaymaker',
#  'olympianism',
#  'terebratuline',
#  'usurer',
#  'winze',
#  'syncotyledonous',
#  'bivoluminous',
#  'hatherlite',
#  'hubert',
#  'slagless',
#  'recoct',
#  'tanyard',
#  'unforbid',
#  'debiteuse',
#  'decarbonizer',
#  'pronic',
#  'coattailed',
#  'interventional',
#  'mastatrophia',
#  'creephole',
#  'burdensomeness',
#  'curiology',
#  'inconceivably',
#  'lumbang',
#  'vauquelinite',
#  'stylomastoid',
#  'sleekly',
#  'kulturkampf',
#  'calydonian',
#  'dispossessory',
#  'vasectomy',
#  'amphigory',
#  'howler',
#  'unrevealedness',
#  'pronominally',
#  'confact',
#  'acromial',
#  'mahori',
#  'luridly',
#  'khu',
#  'irreparability',
#  'sistle',
#  'battlement',
#  'dukeling',
#  'aligreek',
#  'scotomatic',
#  'unaccredited',
#  'nonadhesion',
#  'pronationalistic',
#  'imitatrix',
#  'worrying',
#  'alkoxide',
#  'sphacel',
#  'hemafibrite',
#  'tripewoman',
#  'carbonylene',
#  'arains',
#  'phrenogastric',
#  'capsian',
#  'carnic',
#  'uronic',
#  'pyran',
#  'zoanthid',
#  'tendential',
#  'motherless',
#  'ovigenic',
#  'unattaint',
#  'outpurl',
#  'sodomitess',
#  'tempersome',
#  'stigmatize',
#  'newsprint',
#  'archplotter',
#  'pseudoscorpion',
#  'tesseradecade',
#  'unpoignard',
#  'miserabilism',
#  'randing',
#  'uninterruptible',
#  'airish',
#  'phlebosclerotic',
#  'tractility',
#  'phrenopericardiac',
#  'azotorrhoea',
#  'fundal',
#  'plashy',
#  'underroot',
#  'cumberment',
#  'puzzleheadedly',
#  'overlap',
#  'unwoful',
#  'anaptomorphidae',
#  'mumphead',
#  'uroscopist',
#  'requiescence',
#  'subtarget',
#  'ovogonium',
#  'metic',
#  'overluxurious',
#  'vincibility',
#  'misadvise',
#  'inconscient',
#  'apinage',
#  'sapling',
#  'codheaded',
#  'biophysiological',
#  'foreordain',
#  'gymnurine',
#  'pomatomus',
#  'cobblerfish',
#  'viperously',
#  'wocheinite',
#  'mastication',
#  'sinisterness',
#  'overspeculative',
#  'autoceptive',
#  'mudee',
#  'unbowered',
#  'arhatship',
#  'postulnar',
#  'butlerlike',
#  'cholepoietic',
#  'grapeshot',
#  'sechium',
#  'semifiscal',
#  'solipsismal',
#  'untucked',
#  'staphylodialysis',
#  'gulaman',
#  'xyridales',
#  'pneumograph',
#  'addrest',
#  'lactam',
#  'sentimental',
#  'cicad',
#  'hexamerism',
#  'plumbiferous',
#  'tyranni',
#  'arecaine',
#  'windfallen',
#  'techiness',
#  'toxalbumose',
#  'shikar',
#  'unhalted',
#  'tricenary',
#  'alumium',
#  'monocerous',
#  'sleeveen',
#  'zoogonic',
#  'malebranchism',
#  'tetrachloromethane',
#  'dysluite',
#  'hewer',
#  'paulist',
#  'gardy',
#  'urination',
#  'veterancy',
#  'prodenominational',
#  'dyslalia',
#  'goosery',
#  'monogamousness',
#  'encloak',
#  'gymnostomous',
#  'routhie',
#  'semidomesticated',
#  'bellicism',
#  'resultive',
#  'themselves',
#  'subvert',
#  'chromaphil',
#  'dowel',
#  'floralia',
#  'gleeman',
#  'protonitrate',
#  'unepiscopally',
#  'wanderable',
#  'inopportunely',
#  'trirectangular',
#  'unspectacled',
#  'sialosyrinx',
#  'erythroglucin',
#  'inclemently',
#  'clause',
#  'carbomethene',
#  'cephalopterus',
#  'diselenide',
#  'toup',
#  'apocha',
#  'femalize',
#  'adiaphoristic',
#  'homemade',
#  'epicly',
#  'oatlike',
#  'tubularly',
#  'undecorousness',
#  'quirl',
#  'frogman',
#  'paratrichosis',
#  'gloomth',
#  'oscarellidae',
#  'unbuttonment',
#  'heartwort',
#  'pterosauri',
#  'fabrikoid',
#  'parotidectomy',
#  'coronillin',
#  'superrefined',
#  'hesychasm',
#  'nonrepresentationalism',
#  'consign',
#  'regurgitant',
#  'hominisection',
#  'hematosis',
#  'banked',
#  'exobasidiaceae',
#  'festivity',
#  'melomaniac',
#  'prelectress',
#  'showboard',
#  'sulphovanadate',
#  'campanularidae',
#  'oxyhaloid',
#  'hogger',
#  'tariffism',
#  'haplessly',
#  'deperditely',
#  'atropine',
#  'knobber',
#  'squeamous',
#  'universalism',
#  'chlorazide',
#  'opposing',
#  'roundish',
#  'corporeals',
#  'premodify',
#  'oenothera',
#  'multiflagellated',
#  'serology',
#  'dysmetria',
#  'contorted',
#  'unwebbing',
#  'sinapoline',
#  'dewy',
#  'algidness',
#  'allonymous',
#  'twindle',
#  'ame',
#  'unsinkability',
#  'tulwar',
#  'retransmit',
#  'triply',
#  'bemirement',
#  'coiture',
#  'protoblast',
#  'lignoceric',
#  'rushen',
#  'shrite',
#  'lixiviate',
#  'cotemporaneously',
#  'aggravating',
#  'novatrix',
#  'virtualism',
#  'urethroperineal',
#  'besoothement',
#  'paramastigate',
#  'electropolar',
#  'eftsoons',
#  'uncalculatingly',
#  'ternariant',
#  'trustlessly',
#  'metacinnabarite',
#  'wigger',
#  'kos',
#  'spalt',
#  'supererogation',
#  'pleiochromic',
#  'undulationist',
#  'disfashion',
#  'applaudable',
#  'epactal',
#  'retaliation',
#  'bardess',
#  'clinamina',
#  'damnii',
#  'overconsume',
#  'superconductor',
#  'satiate',
#  'uria',
#  'concert',
#  'sursumvergence',
#  'appearance',
#  'osteocarcinoma',
#  'padronism',
#  'ungenerated',
#  'crookedness',
#  'tritonymph',
#  'erugatory',
#  'winterdykes',
#  'sailorman',
#  'unfrightenable',
#  'katik',
#  'nonvillager',
#  'coretomy',
#  'fastidiosity',
#  'taenite',
#  'donjon',
#  'cannabism',
#  'eluate',
#  'lyonnaise',
#  'titanite',
#  'bagre',
#  'chrysohermidin',
#  'balarama',
#  'ghatwazi',
#  'heiressdom',
#  'vibrating',
#  'frankable',
#  'holocrystalline',
#  'untidy',
#  'venetic',
#  'extent',
#  'attinge',
#  'depetticoat',
#  'brevicipitidae',
#  'ichthyophthalmite',
#  'screeny',
#  'loined',
#  'romancy',
#  'noncrenate',
#  'orchidorrhaphy',
#  'frogskin',
#  'holdenite',
#  'myxinoidei',
#  'ninnyish',
#  'nonwalking',
#  'propagandism',
#  'isatate',
#  'theologicometaphysical',
#  'unnaturalism',
#  'spongoblast',
#  'omber',
#  'napoo',
#  'forcer',
#  'paraquinone',
#  'alkyl',
#  'reoil',
#  'underscale',
#  'pictogram',
#  'dealer',
#  'jussion',
#  'hickwall',
#  'axlesmith',
#  'malapertly',
#  'bocce',
#  'geason',
#  'acetylbenzene',
#  'phoradendron',
#  'praxiology',
#  'preaddition',
#  'balete',
#  'camaldolesian',
#  'peritoneopathy',
#  'addability',
#  'coreometer',
#  'pickthankly',
#  'inconvinced',
#  'undemagnetizable',
#  'fasciate',
#  'hendecoic',
#  'broadmouth',
#  'quag',
#  'thyreoglossal',
#  'nitrotoluene',
#  'polygynic',
#  'enfiled',
#  'trihemeral',
#  'platonicalness',
#  'anthography',
#  'intercultural',
#  'cotte',
#  'keta',
#  'phosphorous',
#  'septenarian',
#  'unteem',
#  'demeritorious',
#  'ronsardian',
#  'underclothed',
#  'jobbernowlism',
#  'xylostromata',
#  'naigie',
#  'unbeautifully',
#  'unexamining',
#  'unlevelly',
#  'bardesanite',
#  'trigintennial',
#  'surly',
#  'iteaceae',
#  'subcoracoid',
#  'botrydium',
#  'curryfavel',
#  'improver',
#  'secessia',
#  'stroking',
#  'rhopalic',
#  'grush',
#  'vouchable',
#  'moanless',
#  'sodiotartrate',
#  'trisected',
#  'ingotman',
#  'noncoagulability',
#  'arthral',
#  'butterflylike',
#  'rowed',
#  'chamaecrista',
#  'gnatcatcher',
#  'uncurricularized',
#  'myriapodous',
#  'shelleyan',
#  'metrologue',
#  'maharashtri',
#  'imbruement',
#  'exultancy',
#  'phenobarbital',
#  'submucosal',
#  'veneficous',
#  'bang',
#  'carcharhinus',
#  'producal',
#  'cromorna',
#  'plim',
#  'oligochrome',
#  'paced',
#  'orderliness',
#  'polyonymic',
#  'pyohemothorax',
#  'puttywork',
#  'sluddery',
#  'noncoincident',
#  'orbic',
#  'pseudomoral',
#  'trisul',
#  'sternofacialis',
#  'planular',
#  'dayakker',
#  'thoraces',
#  'azonaphthalene',
#  'bluely',
#  'semistarved',
#  'confederator',
#  'undescended',
#  'propagational',
#  'hyperhilarious',
#  'homogenic',
#  'tenchweed',
#  'feticide',
#  'inappetent',
#  'mappist',
#  'lingula',
#  'orkhon',
#  'corkmaking',
#  'philharmonic',
#  'unresistingness',
#  'procommunist',
#  'vitrophyre',
#  'unweb',
#  'truckler',
#  'preoppression',
#  'phaenantherous',
#  'reglow',
#  'illegalness',
#  'molybdonosus',
#  'photophile',
#  'nundine',
#  'substruct',
#  'polychromia',
#  'trabacolo',
#  'chrysopidae',
#  'bergschrund',
#  'heartikin',
#  'solaristically',
#  'uncapsizable',
#  'rarefy',
#  'melanagogue',
#  'month',
#  'brin',
#  'earthslide',
#  'villainage',
#  'nacred',
#  'grubbed',
#  'forebemoaned',
#  'intervascular',
#  'fulminancy',
#  'lingel',
#  'multilamellar',
#  'wineskin',
#  'provedly',
#  'sleepmarken',
#  'unrowed',
#  'vineyarding',
#  'irrotational',
#  'quintocubitalism',
#  'gardenful',
#  'acromyotonus',
#  'inomyoma',
#  'bacteriological',
#  'infallibilism',
#  'polemarch',
#  'pupilate',
#  'undergabble',
#  'coruscate',
#  'blellum',
#  'clitoris',
#  'betulinol',
#  'goustrous',
#  'trottles',
#  'glyphograph',
#  'exogamous',
#  'uplimber',
#  'musicality',
#  'ebullioscopic',
#  'villa',
#  'sarcocystis',
#  'rigwiddie',
#  'stunter',
#  'erythroxylum',
#  'chumashan',
#  'alfreda',
#  'inappropriate',
#  'honeyless',
#  'pussyfooted',
#  'polymethylene',
#  'aluminite',
#  'cornroot',
#  'luteolin',
#  'trihemimeral',
#  'galegine',
#  'pal',
#  'could',
#  'inchoant',
#  'discrepant',
#  'shroudless',
#  'heteradenia',
#  'arnoseris',
#  'clitelliferous',
#  'oecumenicalism',
#  'undon',
#  'chinamania',
#  'grosz',
#  'osmograph',
#  'albi',
#  'consummativeness',
#  'socket',
#  'unsloped',
#  'unsatirized',
#  'lustrification',
#  'reclinated',
#  'endosporium',
#  'proclassical',
#  'repaying',
#  'unspecked',
#  'smut',
#  'wholesomeness',
#  'arthrous',
#  'pythius',
#  'unpermanent',
#  'rotation',
#  'helvetii',
#  'antiabrasion',
#  'ditchwater',
#  'perscribe',
#  'schoollike',
#  'spottedly',
#  'billyhood',
#  'crapshooter',
#  'redoubling',
#  'dialogistically',
#  'pediatrist',
#  'abstractly',
#  'unswanlike',
#  'ultragallant',
#  'superservice',
#  'felicitate',
#  'onewhere',
#  'charca',
#  'ref',
#  'inspan',
#  'unscoring',
#  'topmaking',
#  'signator',
#  'cancerdrops',
#  'saurodont',
#  'grantable',
#  'undeserted',
#  'cheeky',
#  'sillago',
#  'interlaid',
#  'admiration',
#  'capitolian',
#  'femininely',
#  'lanciform',
#  'prevogue',
#  'subdrill',
#  'nabob',
#  'praise',
#  'sybarite',
#  'epitoniidae',
#  'tentage',
#  'inserted',
#  'sagittiform',
#  'gristbite',
#  'unrenderable',
#  'breath',
#  'branching',
#  'forfar',
#  'evangelization',
#  'photolithographic',
#  'sensor',
#  'columbiferous',
#  'dermalith',
#  'nowanights',
#  'phenylacetic',
#  'unleakable',
#  'notioned',
#  'parse',
#  'convocative',
#  'reassessment',
#  'nowroze',
#  'capelet',
#  'discovert',
#  'unprying',
#  'unterribly',
#  'depthen',
#  'tympanichordal',
#  'subtread',
#  'shoeing',
#  'scacchite',
#  'intercoracoid',
#  'copyist',
#  'intracarpal',
#  'sphincterotomy',
#  'hyporhachis',
#  'acarotoxic',
#  'gape',
#  'meriquinoidal',
#  'noneditorial',
#  'seawoman',
#  'qualificatory',
#  'fenbank',
#  'basis',
#  'alleghenian',
#  'knocking',
#  'germaneness',
#  'overfunctioning',
#  'vesiculata',
#  'deplenish',
#  'poor',
#  'hospital',
#  'trogones',
#  'foxtongue',
#  'revue',
#  'prominent',
#  'fyke',
#  'catalogia',
#  'lihyanite',
#  'pneumochirurgia',
#  'superstructural',
#  'tympanites',
#  'bunga',
#  'triticism',
#  'predisponency',
#  'sclerodermitis',
#  'wishable',
#  'zeugobranchia',
#  'cotyledonar',
#  'steadiment',
#  'chevronwise',
#  'dejeune',
#  'pelorus',
#  'uniter',
#  'grisounite',
#  'drupal',
#  'outseek',
#  'syringin',
#  'inapparent',
#  'scalp',
#  'prepolitical',
#  'outswing',
#  'widespreadly',
#  'mellivorous',
#  'flaillike',
#  'successfully',
#  'khutuktu',
#  'goi',
#  'steve',
#  'trisylabic',
#  'nonconservative',
#  'diluvian',
#  'nictate',
#  'schedulate',
#  'ungrantable',
#  'duncery',
#  'arakawaite',
#  'soken',
#  'upbelch',
#  'grandparental',
#  'jesuitist',
#  'circumesophagal',
#  'infinitarily',
#  'fleyland',
#  'circumitineration',
#  'purpurescent',
#  'democratical',
#  'cupped',
#  'counterreformation',
#  'citral',
#  'embossman',
#  'fungilliform',
#  'owlet',
#  'myriophyllum',
#  'psorospermiasis',
#  'enchelycephali',
#  'wileless',
#  'witan',
#  'ivorine',
#  'exclusively',
#  'flirtingly',
#  'shinty',
#  'snorer',
#  'archvestryman',
#  'starets',
#  'tangaloa',
#  'promilitarist',
#  'perchlorethylene',
#  'disorderer',
#  'armonica',
#  'poetless',
#  'stomachlessness',
#  'theologer',
#  'mucosopurulent',
#  'zaporogue',
#  'geomagnetic',
#  'athanor',
#  'pathometabolism',
#  'offaling',
#  'johnathan',
#  'cyprinoid',
#  'thioarseniate',
#  'counterequivalent',
#  'mulefooted',
#  'selectiveness',
#  'anthecology',
#  'amatrice',
#  'photoelectrical',
#  'senseless',
#  'alderamin',
#  'gamma',
#  'odontoplerosis',
#  'questman',
#  'supersonic',
#  'tenancy',
#  'thready',
#  'autosight',
#  'reedlike',
#  'actinomyxidia',
#  'morbifical',
#  'renounceable',
#  'communistery',
#  'pseudohallucination',
#  'uninhabitedness',
#  'wold',
#  'exudence',
#  'nothingness',
#  'hecatontarchy',
#  'vipresident',
#  'screwhead',
#  'dorado',
#  'burel',
#  'samba',
#  'ropedance',
#  'scrive',
#  'agastache',
#  'inemotivity',
#  'conchylium',
#  'radiatoporose',
#  'sompner',
#  'ungual',
#  'particular',
#  'millincost',
#  'lora',
#  'asecretory',
#  'malleiform',
#  'truthiness',
#  'reeler',
#  'di',
#  'phytophilous',
#  'separatist',
#  'weediness',
#  'wardmote',
#  'amblydactyla',
#  'mutuary',
#  'enteroanastomosis',
#  'monitorship',
#  'paludism',
#  'shivery',
#  'reducing',
#  'skeletal',
#  'scooping',
#  'dendritic',
#  'rhinopharyngeal',
#  'khagiarite',
#  'eiresione',
#  'bacteriophage',
#  'prenanthes',
#  'asor',
#  'sericterium',
#  'sportfully',
#  'ascomycete',
#  'unhosed',
#  'bangiaceae',
#  'cancellation',
#  'departure',
#  'reoxygenize',
#  'protandric',
#  'formativeness',
#  'malthusiast',
#  'ctenoid',
#  'polyoeciously',
#  'telemeteorography',
#  'stoppeur',
#  'cagit',
#  'fashionize',
#  'anastatic',
#  'tricyclic',
#  'scurrilousness',
#  'pajama',
#  'cerebellum',
#  'florivorous',
#  'magirological',
#  'sextuberculate',
#  'unfurnished',
#  'lapidicolous',
#  'meccano',
#  'rechar',
#  'apiales',
#  'rindless',
#  'afternote',
#  'millettia',
#  'lapidity',
#  'unconvertedness',
#  'decurvation',
#  'unperseverance',
#  'hematometer',
#  'amphitheatric',
#  'epidemic',
#  'emphaticalness',
#  'kanap',
#  'sophian',
#  'predation',
#  'preincrease',
#  'windberry',
#  'reducement',
#  'sheepherder',
#  'antiatheist',
#  'osteosclerosis',
#  'eikonology',
#  'thymolphthalein',
#  'deerdrive',
#  'radectomy',
#  'gesithcund',
#  'proditoriously',
#  'centrale',
#  'pinealism',
#  'isohyet',
#  'untiring',
#  'horvatian',
#  'ethylhydrocupreine',
#  'pansinusitis',
#  'nonfailure',
#  'retrocervical',
#  'undermarshalman',
#  'pseudospermic',
#  'rhodophane',
#  'otherhow',
#  'huggermuggery',
#  'unextenuating',
#  'nemathelminth',
#  'bluebird',
#  'lashlite',
#  'cavalero',
#  'noninductivity',
#  'comfortlessly',
#  'pentadecahydrate',
#  'merorganize',
#  'mizar',
#  'phellogenetic',
#  'landright',
#  'nebule',
#  'nonvalidity',
#  'numismatic',
#  'show',
#  'pistachio',
#  'supermedial',
#  'phene',
#  'phocenate',
#  'flagitiously',
#  'attently',
#  'berylate',
#  'unbreakableness',
#  'broad',
#  'xanthophyll',
#  'unclassical',
#  'pseudoministerial',
#  'divinely',
#  'alt',
#  'uncurled',
#  'sicyonic',
#  'polycratic',
#  'semibarbarous',
#  'urethrameter',
#  'hexaspermous',
#  'unhermetic',
#  'xanthochroic',
#  'unkneaded',
#  'pygopodes',
#  'playfulness',
#  'reassurance',
#  'macle',
#  'agnatic',
#  'hydrological',
#  'amyclas',
#  'brushiness',
#  'humoralist',
#  'dissemilative',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
sorted('love') == sorted('hate')
# Out:
# False

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('lives')
# Out:
# 'eilsv'

# %%
'/'.join(['a','b','c'])
# Out:
# 'a/b/c'

# %%
def anagram(word):
    return [w for w in wordclean if signature(w) == signature(word)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 1 loops, best of 3: 1.22 s per loop

# %%
words_bysig = {}

for word in wordclean:
    words_bysig[signature(word)].append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-198314f94f4a> in <module>()
#       2
#       3 for word in wordclean:
# ----> 4     words_bysig[signature(word)].append(word)
#
# KeyError: 'a'

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
words_bysig
# Out:
# defaultdict(<class 'list'>, {'efllrssstuy': ['stressfully'], 'acdeelortu': ['edulcorate'], 'bdegioprr': ['probridge'], 'aaagilnr': ['langarai'], 'accenotx': ['texcocan'], 'abloory': ['obolary'], 'aacehlprty': ['archetypal'], 'aagilnoprs': ['sporangial'], 'fioorsu': ['furioso'], 'begij': ['bejig'], 'aadeeiimnnoprtttz': ['departmentization'], 'acehinpr': ['phaneric'], 'aceimnorstu': ['neuromastic'], 'adghhilnry': ['highlandry'], 'aacehhlooprtx': ['cephalothorax'], 'acffiilno': ['officinal'], 'aadddeinnrstuz': ['unstandardized'], 'abcceiiilnsstuy': ['unaccessibility'], 'adeimrrsw': ['misreward'], 'aikmnnrtu': ['manitrunk'], 'ceeiimnopprt': ['imperception'], 'aaglnorrsttuy': ['strangulatory'], 'abloprswy': ['blowspray'], 'ehioprssttt': ['prosthetist'], 'abgghinnrsu': ['bushranging'], 'ceirst': ['certis', 'steric'], 'achorrsy': ['chrysaor'], 'aegjnorr': ['jargoner'], 'aginry': ['grainy'], 'eeeirstz': ['esterize'], 'deeflx': ['deflex', 'flexed'], 'acirrtu': ['urartic'], 'cehinooprs': ['rhinoscope'], 'aghilnss': ['slangish', 'slashing'], 'aeiiinnorrsttt': ['interstriation'], 'adeimrtxy': ['taxidermy'], 'cdeiims': ['disemic'], 'aaceeggimnot': ['agamogenetic'], 'aglnoooprsy': ['parsonology'], 'iinos': ['oisin'], 'deiimsw': ['midwise'], 'aacnorrstt': ['transactor'], 'cdeiimnntt': ['indictment'], 'deiorssu': ['desirous', 'siderous'], 'cehiilnopru': ['neurophilic'], 'ceinrstu': ['turnices'], 'aeeiklnrrw': ['warrenlike'], 'deehinnrrssuu': ['unhurriedness'], 'aduvy': ['vaudy'], 'elrru': ['lurer', 'ruler'], 'agiotu': ['agouti'], 'bdilmoos': ['disbloom'], 'begglo': ['boggle'], 'aelnoppy': ['polypean'], 'eilnnt': ['linnet', 'linten'], 'aegilnnssst': ['lastingness'], 'accdelmnostuuy': ['unaccustomedly'], 'accdiillnoop': ['diploconical'], 'eellorssv': ['loverless'], 'chimnoopt': ['monopitch'], 'deegnoorrstt': ['sondergotter'], 'aaeeelmprttty': ['attemperately'], 'hillpu': ['uphill'], 'aahllmn': ['hallman'], 'acelmnss': ['calmness'], 'adeehilntu': ['heulandite'], 'aaadhnr': ['dharana'], 'aaeilprstv': ['palaverist'], 'aeimmnpstu': ['pneumatism'], 'aanwyy': ['anyway'], 'aaacdeeilox': ['oxalidaceae'], 'eeegnoprrssuu': ['supergenerous'], 'aaailpt': ['alipata'], 'ghiinnorsu': ['nourishing'], 'eegrrv': ['verger'], 'ekknopprrsu': ['kornskeppur'], 'filorsty': ['frostily'], 'ahimnnnsu': ['unmannish'], 'acehhloppsuy': ['hypocephalus'], 'aeelnrssssst': ['starlessness'], 'aeghnooprrstuuy': ['euryprognathous'], 'immsstu': ['summist'], 'aeinprtx': ['expirant'], 'abhiiloopsttty': ['photostability'], 'aacdeehr': ['headrace'], 'dehiilpsy': ['syphilide'], 'abccilmmnnouuy': ['uncommunicably'], 'eeeilnnprtvy': ['preveniently'], 'aabilrtttu': ['attributal'], 'aaacddeeehlrsty': ['acetaldehydrase'], 'adelnsss': ['sandless'], 'ccdioosuu': ['occiduous'], 'bddeiimoor': ['bromiodide'], 'acdelooooprstu': ['alectoropodous'], 'aaehmnprs': ['phraseman'], 'deefgiimru': ['demifigure'], 'deffiorty': ['defortify'], 'acdlopru': ['producal'], 'aaaiilnnqrtuy': ['antiquarianly'], 'abeeegmmorst': ['mesobregmate'], 'aceinsstt': ['cattiness', 'tacitness'], 'cehiiloorstu': ['leiotrichous'], 'eekorrv': ['revoker'], 'elnosssw': ['snowless'], 'egghilnssssu': ['sluggishness'], 'abdilryz': ['lazybird'], 'acceeissv': ['accessive'], 'aaeeiilnnprtt': ['interpalatine'], 'cennrsu': ['scunner'], 'aeeimnprrsy': ['preseminary'], 'adelmnoort': ['tremolando'], 'girw': ['wrig'], 'aacehiilnorrrstt': ['olecranarthritis'], 'aabcelorstt': ['ceratoblast'], 'aaeghimnp': ['amphigean'], 'abdddeinnsu': ['undisbanded'], 'aaadeginpp': ['genipapada'], 'abekmorx': ['boxmaker'], 'abensu': ['unbase'], 'eillwy': ['willey'], 'abdeeehilrt': ['hereditable'], 'ahoprruw': ['upharrow'], 'aceehrrsw': ['archsewer'], 'cemot': ['comet'], 'dghiiinpsw': ['dishwiping'], 'almnoow': ['woolman'], 'ccimnooty': ['monocytic'], 'acefinstu': ['infuscate'], 'dehrswy': ['shrewdy'], 'ceeeeeillnoopprt': ['enteroepiplocele'], 'bghnotuu': ['unbought'], 'afiilllnuy': ['unfilially'], 'hilmmoossty': ['homostylism'], 'aaaceiiillnoprsttuz': ['ultraspe ...

# %%
def anagram_fast(word):
    return words_bysig[signature(word)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}

# %%
len(anagrams_all)
# Out:
# 32890

# %%
# %timeit anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}
# Out:
# 1 loops, best of 3: 861 ms per loop
